# %%
import requests 
from bs4 import BeautifulSoup

# %%
req = requests.get("https://innovatureinc.com/big-data-and-social-media-for-better-marketing/")

soup = BeautifulSoup(req.content,"html.parser")
print(soup.get_text())
# Out:
# Big Data And Social Media For Better Marketing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Why Us?
#
#
#
#
#
#
# WHY US?
#
#
#
# Vietnam's First Integrated Outsourcing Partner
#
#
#
#  With our proven track record of exellence, we are confident that we are the perfect choice for businesses seeking for optimal performance and sustainable growth.
#
#
#
#
#
#
#
#
#
# Reasons to work with us
# Meet Our Leadership Team
# Why Outsource to Vietnam?
#
#
#
#
#
# X
#
#
#
#
#
#
#
#
#
#
#
# Our Solutions
#
#
#
#
#
#
# Above & Beyond Services Delivery
#
#
#
#
# We provide services but also offer tailored solutions that help our clients to enhance their overall performance.
#
#
#
#
#
#
#
#
#
# Accounting and Finance Services
# ...
